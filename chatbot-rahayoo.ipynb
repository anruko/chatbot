# %%
pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip download nltk
# Out:
# ...
#
#   File was already downloaded c:\users\lenovo\documents\college\bangkit\capstone\chatbot\nltk-3.8.1-py3-none-any.whl
# ...
#   File was already downloaded c:\users\lenovo\documents\college\bangkit\capstone\chatbot\click-8.1.3-py3-none-any.whl
# ...
#   File was already downloaded c:\users\lenovo\documents\college\bangkit\capstone\chatbot\joblib-1.2.0-py3-none-any.whl
# ...
#   File was already downloaded c:\users\lenovo\documents\college\bangkit\capstone\chatbot\regex-2023.5.5-cp310-cp310-win_amd64.whl
# ...
#   File was already downloaded c:\users\lenovo\documents\college\bangkit\capstone\chatbot\tqdm-4.65.0-py3-none-any.whl
# ...
#   File was already downloaded c:\users\lenovo\documents\college\bangkit\capstone\chatbot\colorama-0.4.6-py2.py3-none-any.whl
# Successfully downloaded nltk regex click joblib tqdm colorama

# %%
#Fine-Tune
pip install --upgrade openai
# Out:
#   Cell In[3], line 2
#     pip install --upgrade openai
#         ^
# SyntaxError: invalid syntax

# %%
import nltk
nltk.download('punkt')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import json

def load_data_from_json(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# Contoh penggunaan
file_path = 'chatson.json'  # Ganti dengan path file JSON yang sesuai
json_data = load_data_from_json(file_path)

# Konversi ke dalam format yang diinginkan
training_data = []
intents = json_data['intents']
for intent in intents:
    tag = intent['tag']
    patterns = intent['patterns']
    responses = intent['responses']
    for pattern in patterns:
        training_data.append({
            'message': pattern,
            'response': responses[0]  # Mengambil respon pertama
        })

# Cetak training_data untuk memastikan berhasil
print(training_data)
# Out:
# [{'message': 'Hi', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Hey', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Is anyone there?', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Hi there', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Hello', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Hey there', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Howdy', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Hola', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Bonjour', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Konnichiwa', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Guten tag', 'response': 'Hello there. Tell me how are you feeling today?'}, {'message': 'Ola', 'response': 'Hello t
# ...

# %%
import re
import string
import nltk
import openai
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Preprocessing function
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Tokenization
    tokens = word_tokenize(text)

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Reconstruct the preprocessed text
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# Preprocess the training data
preprocessed_training_data = []
for data in training_data:
    preprocessed_message = preprocess_text(data['message'])
    preprocessed_response = preprocess_text(data['response'])
    preprocessed_training_data.append({
        'message': preprocessed_message,
        'response': preprocessed_response
    })

# Cetak preprocessed_training_data untuk memastikan berhasil
print(preprocessed_training_data)

# Set up your OpenAI API credentials
openai.api_key = 'sk-'

# Prepare the data in the format required by OpenAI API
examples = []
for data in preprocessed_training_data:
    example = {
        'role': 'system',
        'content': 'You are a chatbot that accompanies employees after work',
    }
    examples.append(example)

    example = {
        'role': 'user',
        'content': data['message'],
    }
    examples.append(example)

    example = {
        'role': 'assistant',
        'content': data['response'],
    }
    examples.append(example)

# Rest of the code remains the same...
# Out:
# [{'message': 'hi', 'response': 'hello there tell me how are you feeling today'}, {'message': 'hey', 'response': 'hello there tell me how are you feeling today'}, {'message': 'is anyone there', 'response': 'hello there tell me how are you feeling today'}, {'message': 'hi there', 'response': 'hello there tell me how are you feeling today'}, {'message': 'hello', 'response': 'hello there tell me how are you feeling today'}, {'message': 'hey there', 'response': 'hello there tell me how are you feeling today'}, {'message': 'howdy', 'response': 'hello there tell me how are you feeling today'}, {'message': 'hola', 'response': 'hello there tell me how are you feeling today'}, {'message': 'bonjour', 'response': 'hello there tell me how are you feeling today'}, {'message': 'konnichiwa', 'response': 'hello there tell me how are you feeling today'}, {'message': 'guten tag', 'response': 'hello there tell me how are you feeling today'}, {'message': 'ola', 'response': 'hello there tell me how are yo
# ...

# %%
from sklearn.model_selection import train_test_split

# Extract the messages and responses from the data
messages = [item['message'] for item in preprocessed_training_data]
responses = [item['response'] for item in preprocessed_training_data]

# Split the data into training and testing sets
train_messages, test_messages, train_responses, test_responses = train_test_split(
    messages, responses, test_size=0.2, random_state=42
)

# Combine the messages and responses back into training and testing data dictionaries
training_data = [{'message': msg, 'response': resp} for msg, resp in zip(train_messages, train_responses)]
testing_data = [{'message': msg, 'response': resp} for msg, resp in zip(test_messages, test_responses)]

# Print the training and testing data
print("Training Data:")
print(training_data)
print("\nTesting Data:")
print(testing_data)
# Out:
# Training Data:
# ...

# %%
jsonl_data = []
for data in training_data:
    jsonl_data.append(json.dumps({"prompt": data["message"], "completion": data["response"]}))

# Specify the file path where you want to save the JSONL file
file_path = 'C:/Users/LENOVO/Documents/COLLEGE/BANGKIT/CAPSTONE/chatbot/training_data.jsonl'

# Write JSONL data to the specified file path
with open(file_path, 'w') as file:
    file.write('\n'.join(jsonl_data))

print("JSONL file saved at:", file_path)
# Out:
# JSONL file saved at: C:/Users/LENOVO/Documents/COLLEGE/BANGKIT/CAPSTONE/chatbot/training_data.jsonl

# %%
jsonl_data = []
for data in testing_data:
    jsonl_data.append(json.dumps({"prompt": data["message"], "completion": data["response"]}))

# Specify the file path where you want to save the JSONL file
file_path = 'C:/Users/LENOVO/Documents/COLLEGE/BANGKIT/CAPSTONE/chatbot/testing_data.jsonl'

# Write JSONL data to the specified file path
with open(file_path, 'w') as file:
    file.write('\n'.join(jsonl_data))

print("JSONL file saved at:", file_path)
# Out:
# JSONL file saved at: C:/Users/LENOVO/Documents/COLLEGE/BANGKIT/CAPSTONE/chatbot/testing_data.jsonl

# %%
import tensorflow as tf

# Assuming you have a fine-tuned model stored in the 'fine_tuned_model' variable
fine_tunes_model.save("C:/Users/LENOVO/Documents/COLLEGE/BANGKIT/CAPSTONE/chatbot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 import tensorflow as tf
#       3 # Assuming you have a fine-tuned model stored in the 'fine_tuned_model' variable
# ----> 4 fine_tunes_model.save("C:/Users/LENOVO/Documents/COLLEGE/BANGKIT/CAPSTONE/chatbot")
#
# NameError: name 'fine_tunes_model' is not defined

# %%
from transformers import AutoModelForCausalLM

# Assuming you have a fine-tuned model stored in the 'fine_tuned_model' variable
fine_tuned_model = AutoModelForCausalLM.from_pretrained("davinci:ft-personal-2023-05-31-02-20-18", use_auth_token="hf_")  # Replace with your fine-tuned model

# Save the fine-tuned model
fine_tuned_model.save_pretrained("C:/Users/LENOVO/Documents/COLLEGE/BANGKIT/CAPSTONE/chatbot")
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\lib\site-packages\transformers\configuration_utils.py:614, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     612 try:
#     613     # Load from local folder or from cache or download from model Hub and cache
# --> 614     resolved_config_file = cached_file(
#     615         pretrained_model_name_or_path,
#     616         configuration_file,
#     617         cache_dir=cache_dir,
#     618         force_download=force_download,
#     619         proxies=proxies,
#     620         resume_download=resume_download,
#     621         local_files_only=local_files_only,
#     622         use_auth_token=use_auth_token,
#     623         user_agent=user_agent,
#     624         revision=revision,
#     625         subfolder=subfolder,
# ...

# %%
import openai

# Set your OpenAI API key
openai.api_key = "sk-"

# Specify the model name
model_name = "davinci:ft-personal-2023-05-31-02-20-18"

# Save the fine-tuned model
response = openai.models.save(model=model_name)

# Get the saved model ID
saved_model_id = response["ft-"]

# Print the saved model ID
print(f"Saved model ID: {saved_model_id}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 10
#       7 model_name = "davinci:ft-personal-2023-05-31-02-20-18"
#       9 # Save the fine-tuned model
# ---> 10 response = openai.models.save(model=model_name)
#      12 # Get the saved model ID
#      13 saved_model_id = response["ft-o0KrqUKHfPVLf7ZpthyPHTN9"]
#
# AttributeError: module 'openai' has no attribute 'models'

# %%
evaluation_dataset = testing_data  # Your evaluation dataset

# Preprocess the evaluation dataset
preprocessed_evaluation_data = preprocess_dataset(evaluation_dataset)

correct_predictions = 0
total_predictions = len(preprocessed_evaluation_data)

# Generate predictions using the fine-tuned model
for example in preprocessed_evaluation_data:
    input_text = example['input']
    ground_truth_label = example['label']
    
    # Pass the input text to the fine-tuned model to get the predicted output
    predicted_label = fine_tuned_model.predict(input_text)
    
    if predicted_label == ground_truth_label:
        correct_predictions += 1

accuracy = correct_predictions / total_predictions
print(f"Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 evaluation_dataset = testing_data  # Your evaluation dataset
#       3 # Preprocess the evaluation dataset
# ----> 4 preprocessed_evaluation_data = preprocess_dataset(evaluation_dataset)
#       6 correct_predictions = 0
#       7 total_predictions = len(preprocessed_evaluation_data)
#
# NameError: name 'preprocess_dataset' is not defined

# %%
evaluation_dataset = testing_data  # Your evaluation dataset

correct_predictions = 0
total_predictions = len(evaluation_dataset)

# Generate predictions using the fine-tuned model
for example in evaluation_dataset:
    input_text = example['message']
    ground_truth_response = example['response']
    
    # Pass the input text to the fine-tuned model to get the predicted response
    predicted_response = fine_tuned_model.predict("davinci:ft-personal-2023-05-31-02-20-18")
    
    if predicted_response == ground_truth_response:
        correct_predictions += 1

accuracy = correct_predictions / total_predictions
print(f"Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 12
#       9 ground_truth_response = example['response']
#      11 # Pass the input text to the fine-tuned model to get the predicted response
# ---> 12 predicted_response = fine_tuned_model.predict("davinci:ft-personal-2023-05-31-02-20-18")
#      14 if predicted_response == ground_truth_response:
#      15     correct_predictions += 1
#
# NameError: name 'fine_tuned_model' is not defined

# %%
from sklearn.metrics import accuracy_score
import time

# Function to get predicted labels for a given user input
def get_predicted_labels(user_input):
    messages = examples + [{'role': 'user', 'content': user_input}]
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.8,
    )
    assistant_response = response['choices'][0]['message']['content']
    return assistant_response  # Return the predicted label (response) generated by the chatbot

# Prepare true labels and predicted labels for the evaluation dataset
true_labels = []  # List to store true labels from your evaluation dataset
predicted_labels = []  # List to store predicted labels generated by the chatbot

counter = 0

for data in preprocessed_training_data:
    if counter >= 2:
        time.sleep(60)
        counter = 0
    true_labels.append(data['response'])  # Assuming 'response' field contains the true label
    predicted_label = get_predicted_labels(data['message'])
    predicted_labels.append(predicted_label)
    counter += 1

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.14492753623188406

# %%
test_model()
# Out:
# User: hello there
# Assistant: Hello! How can I assist you today?
# User: I just got home from work
# Assistant: How was your day at work today?
# User: I'm feeling great today. My colleague praised about my work and told that she was helped with it
# Assistant: That's great to hear. You should be proud of your accomplishments. Keep up the good work.
# User: Thanks!
# Assistant: You're welcome!
# User: I guess we're done. I'm gonna rest now
# Assistant: Sure, take care of yourself and get some rest. Remember that I'm here if you need someone to talk to. Goodbye!
# User: see you later
# Chatbot session ended.
